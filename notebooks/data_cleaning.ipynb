# %%
import pandas as pd
import numpy as np
import re
import unicodedata
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("data/raw/goodreads.csv")
df1
# Out:
#           Shelf                                              Title  \
# 0      children                                    Charlotte’s Web
# 1      children  Harry Potter and the Philosopher’s Stone (Harr...
# 2      children                                  The Little Prince
# 3      children                                    The Giving Tree
# 4      children                          Where the Wild Things Are
# ..          ...                                                ...
# 732  philosophy            Groundwork of the Metaphysics of Morals
# 733  philosophy                            Phenomenology of Spirit
# 734  philosophy  Discourse on Method and Meditations on First P...
# 735  philosophy                                         The Plague
# 736  philosophy                                             Utopia
#
#                             Author  Rating  Publication Year  \
# 0                       E.B. White    4.21            1952.0
# 1                     J.K. Rowling    4.47            1997.0
# 2         Antoine de Saint-Exupéry    4.33            1943.0
# 3                 Shel Silverstein    4.38            1964.0
# 4                   Maurice Sendak    4.25            1963.0
# ..                             ...     ...               ...
# 732                  Immanuel Kant    3.83            1785.0
# 733  Georg Wilhelm Friedrich Hegel    3.96            1807.0
# 734                 René Descartes    3.77            1637.0
# 735                   Albert Camus    4.02            1947.0
# 736                    Thomas More    3.55            1516.0
#
#                                                   Link
# 0    https://www.goodreads.com/book/show/24178.Char...
# 1    https://www.goodreads.com/book/show/42844155-h...
# 2    https://www.goodreads.com/book/show/157993.The...
# 3    https://www.goodreads.com/book/show/370493.The...
# 4    https://www.goodreads.com/book/show/19543.Wher...
# ..                                                 ...
# 732  https://www.goodreads.com/book/show/60080.Grou...
# 733  https://www.goodreads.com/book/show/9454.Pheno...
# 734  https://www.goodreads.com/book/show/31862.Disc...
# 735  https://www.goodreads.com/book/show/11989.The_...
# 736   https://www.goodreads.com/book/show/18414.Utopia
#
# [737 rows x 6 columns]

# %%
df1 = df1.rename(columns={
    "Shelf": "Genre",
    "Rating": "Average Rating"
})

# %%
df2 = pd.read_csv("data/raw/openlibrary.csv")
df2
# Out:
#        Genre                                 Title  \
# 0    fantasy                                Lilith
# 1    fantasy                       The Sea Fairies
# 2    fantasy            The Phoenix and the Carpet
# 3    fantasy                  The Enchanted Castle
# 4    fantasy                            Phantastes
# ..       ...                                   ...
# 652   memoir                         Manon Lescaut
# 653   memoir  The Song of Hiawatha and Other Poems
# 654   memoir                      Crying in H Mart
# 655   memoir                            Finding Me
# 656   memoir                      Lettres persanes
#
#                                                 Author  Average Rating  \
# 0                                     George MacDonald            3.20
# 1                                        L. Frank Baum            3.33
# 2                                         Edith Nesbit            3.10
# 3                                         Edith Nesbit            4.18
# 4                                     George MacDonald            3.83
# ..                                                 ...             ...
# 652  Abbé Prévost, F. C. Green, felix crespo, Pr&ea...            4.00
# 653                         Henry Wadsworth Longfellow            3.80
# 654                                    Michelle Zauner            3.82
# 655                                        Viola Davis            3.78
# 656  Charles-Louis de Secondat baron de La Brède e...            3.50
#
#      Ratings Count  Publication Year  \
# 0              5.0            1895.0
# 1              3.0            1911.0
# 2             10.0            1903.0
# 3             11.0            1907.0
# 4             12.0            1850.0
# ..             ...               ...
# 652            4.0            1734.0
# 653            5.0            1800.0
# 654           22.0            2021.0
# 655            9.0            2022.0
# 656            4.0            1721.0
#
#                                           Link
# 0       https://openlibrary.org/works/OL15437W
# 1      https://openlibrary.org/works/OL262384W
# 2       https://openlibrary.org/works/OL99539W
# 3       https://openlibrary.org/works/OL99541W
# 4       https://openlibrary.org/works/OL15450W
# ..                                         ...
# 652   https://openlibrary.org/works/OL1132652W
# 653    https://openlibrary.org/works/OL495934W
# 654  https://openlibrary.org/works/OL22448002W
# 655  https://openlibrary.org/works/OL25988701W
# 656    https://openlibrary.org/works/OL453553W
#
# [657 rows x 7 columns]

# %%
df2.drop("Ratings Count", axis=1, inplace=True)

# %%
df2
# Out:
#        Genre                                 Title  \
# 0    fantasy                                Lilith
# 1    fantasy                       The Sea Fairies
# 2    fantasy            The Phoenix and the Carpet
# 3    fantasy                  The Enchanted Castle
# 4    fantasy                            Phantastes
# ..       ...                                   ...
# 652   memoir                         Manon Lescaut
# 653   memoir  The Song of Hiawatha and Other Poems
# 654   memoir                      Crying in H Mart
# 655   memoir                            Finding Me
# 656   memoir                      Lettres persanes
#
#                                                 Author  Average Rating  \
# 0                                     George MacDonald            3.20
# 1                                        L. Frank Baum            3.33
# 2                                         Edith Nesbit            3.10
# 3                                         Edith Nesbit            4.18
# 4                                     George MacDonald            3.83
# ..                                                 ...             ...
# 652  Abbé Prévost, F. C. Green, felix crespo, Pr&ea...            4.00
# 653                         Henry Wadsworth Longfellow            3.80
# 654                                    Michelle Zauner            3.82
# 655                                        Viola Davis            3.78
# 656  Charles-Louis de Secondat baron de La Brède e...            3.50
#
#      Publication Year                                       Link
# 0              1895.0     https://openlibrary.org/works/OL15437W
# 1              1911.0    https://openlibrary.org/works/OL262384W
# 2              1903.0     https://openlibrary.org/works/OL99539W
# 3              1907.0     https://openlibrary.org/works/OL99541W
# 4              1850.0     https://openlibrary.org/works/OL15450W
# ..                ...                                        ...
# 652            1734.0   https://openlibrary.org/works/OL1132652W
# 653            1800.0    https://openlibrary.org/works/OL495934W
# 654            2021.0  https://openlibrary.org/works/OL22448002W
# 655            2022.0  https://openlibrary.org/works/OL25988701W
# 656            1721.0    https://openlibrary.org/works/OL453553W
#
# [657 rows x 6 columns]

# %%
#merging the csvs
df = pd.concat([df1, df2], ignore_index=True)
df
# Out:
#          Genre                                              Title  \
# 0     children                                    Charlotte’s Web
# 1     children  Harry Potter and the Philosopher’s Stone (Harr...
# 2     children                                  The Little Prince
# 3     children                                    The Giving Tree
# 4     children                          Where the Wild Things Are
# ...        ...                                                ...
# 1389    memoir                                      Manon Lescaut
# 1390    memoir               The Song of Hiawatha and Other Poems
# 1391    memoir                                   Crying in H Mart
# 1392    memoir                                         Finding Me
# 1393    memoir                                   Lettres persanes
#
#                                                  Author  Average Rating  \
# 0                                            E.B. White            4.21
# 1                                          J.K. Rowling            4.47
# 2                              Antoine de Saint-Exupéry            4.33
# 3                                      Shel Silverstein            4.38
# 4                                        Maurice Sendak            4.25
# ...                                                 ...             ...
# 1389  Abbé Prévost, F. C. Green, felix crespo, Pr&ea...            4.00
# 1390                         Henry Wadsworth Longfellow            3.80
# 1391                                    Michelle Zauner            3.82
# 1392                                        Viola Davis            3.78
# 1393  Charles-Louis de Secondat baron de La Brède e...            3.50
#
#       Publication Year                                               Link
# 0               1952.0  https://www.goodreads.com/book/show/24178.Char...
# 1               1997.0  https://www.goodreads.com/book/show/42844155-h...
# 2               1943.0  https://www.goodreads.com/book/show/157993.The...
# 3               1964.0  https://www.goodreads.com/book/show/370493.The...
# 4               1963.0  https://www.goodreads.com/book/show/19543.Wher...
# ...                ...                                                ...
# 1389            1734.0           https://openlibrary.org/works/OL1132652W
# 1390            1800.0            https://openlibrary.org/works/OL495934W
# 1391            2021.0          https://openlibrary.org/works/OL22448002W
# 1392            2022.0          https://openlibrary.org/works/OL25988701W
# 1393            1721.0            https://openlibrary.org/works/OL453553W
#
# [1394 rows x 6 columns]

# %%
df.columns = df.columns.str.lower()

# %%
def title(title):
    if pd.isna(title):
        return ""
    # Normalize unicode (fix 'Ã', smart quotes, etc.)
    title = unicodedata.normalize("NFKD", title).encode("ascii", "ignore").decode("utf-8")
    # Lowercase
    title = title.lower()
    # Remove punctuation and extra symbols
    title = re.sub(r"[^a-z0-9\s]", "", title)
    # Remove multiple spaces
    title = re.sub(r"\s+", " ", title).strip()
    return title

# %%
df["title"] = df["title"].apply(title)

# %%
#checking for duplicates
df['title'].value_counts()[df['title'].value_counts() > 1]
# Out:
# title
#                              11
# poems                         6
# l humour                      3
# carnet de notes               3
# humour                        3
#                              ..
# the prince                    2
# james and the giant peach     2
# paradise lost                 2
# on liberty                    2
# tao te ching                  2
# Name: count, Length: 75, dtype: int64

# %%
df = df.drop_duplicates(subset='title', keep='first').reset_index(drop=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#checking for null
df.isnull().sum()
# Out:
# genre                0
# title                0
# author               2
# average rating      55
# publication year    37
# link                 0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (1227, 6)

# %%
df = df.rename(columns={"publication year": "publication_year",
                       "average rating": "average_rating"})

# %%
df["publication_year"] = df["publication_year"].astype(int)

# %%
df["average_rating"] = df["average_rating"].clip(0, 5)

# %%
df
# Out:
#          genre                                              title  \
# 0     children                                     charlottes web
# 1     children  harry potter and the philosophers stone harry ...
# 2     children                                  the little prince
# 3     children                                    the giving tree
# 4     children                          where the wild things are
# ...        ...                                                ...
# 1297    memoir                                         unfinished
# 1298    memoir                                  stone butch blues
# 1300    memoir                                      manon lescaut
# 1301    memoir               the song of hiawatha and other poems
# 1302    memoir                                   lettres persanes
#
#                                                  author  average_rating  \
# 0                                            E.B. White            4.21
# 1                                          J.K. Rowling            4.47
# 2                              Antoine de Saint-Exupéry            4.33
# 3                                      Shel Silverstein            4.38
# 4                                        Maurice Sendak            4.25
# ...                                                 ...             ...
# 1297                              Priyanka Chopra Jonas            4.00
# 1298                                    Leslie Feinberg            4.61
# 1300  Abbé Prévost, F. C. Green, felix crespo, Pr&ea...            4.00
# 1301                         Henry Wadsworth Longfellow            3.80
# 1302  Charles-Louis de Secondat baron de La Brède e...            3.50
#
#       publication_year                                               link
# 0                 1952  https://www.goodreads.com/book/show/24178.Char...
# 1                 1997  https://www.goodreads.com/book/show/42844155-h...
# 2                 1943  https://www.goodreads.com/book/show/157993.The...
# 3                 1964  https://www.goodreads.com/book/show/370493.The...
# 4                 1963  https://www.goodreads.com/book/show/19543.Wher...
# ...                ...                                                ...
# 1297              2021          https://openlibrary.org/works/OL24206176W
# 1298              1993           https://openlibrary.org/works/OL1868110W
# 1300              1734           https://openlibrary.org/works/OL1132652W
# 1301              1800            https://openlibrary.org/works/OL495934W
# 1302              1721            https://openlibrary.org/works/OL453553W
#
# [1227 rows x 6 columns]

# %%
df.to_csv("data/clean/cleaned_data.csv", index=False)

# %%
df["genre"].unique()
# Out:
# array(['children', 'fantasy', 'romance', 'fiction', 'non-fiction',
#        'history', 'biography', 'science', 'humour', 'memoir', 'classics',
#        'mystery', 'thriller', 'young-adult', 'contemporary', 'self-help',
#        'graphic-novels', 'poetry', 'crime', 'philosophy'], dtype=object)

# %%
#import re

#def clean_title(title):
#    title = title.lower().strip()
#    title = re.sub(r'[^a-z\s]', '', title)
#    title = re.sub(r'\s+', ' ', title)
#    return title

# %%
#df['clean_title'] = df['title'].apply(clean_title)

# %%
#from rapidfuzz import fuzz

#potential_dupes = []

#for i in range(len(df)):
#    for j in range(i + 1, len(df)):
#        score = fuzz.ratio(df.iloc[i]['clean_title'], df.iloc[j]['clean_title'])
        
        # Similar title check
 #       if score > 90:
#            same_author = df.iloc[i]['author'].strip().lower() == df.iloc[j]['author'].strip().lower()
            
            # Optional: allow ±1 year difference (sometimes editions differ slightly)
#            year_diff_ok = abs(df.iloc[i]['year'] - df.iloc[j]['year']) <= 1 if 'year' in df.columns else True
            
#            if same_author and year_diff_ok:
#                potential_dupes.append({
#                    'title_1': df.iloc[i]['title'],
#                    'title_2': df.iloc[j]['title'],
#                    'author': df.iloc[i]['author'],
#                    'year': df.iloc[i].get('year', 'N/A'),
#                    'similarity': score
 #               })

# %%
#dupes_df = pd.DataFrame(potential_dupes)
#dupes_df.head(50)

# %%
#duplicate_titles = set(dupes_df['title_2'])
#df = df[~df['title'].isin(duplicate_titles)].reset_index(drop=True)

# %%
sns.set(style="whitegrid", context="talk", palette="muted")

# Optional: increase figure quality for PPT
plt.rcParams["figure.dpi"] = 120
plt.rcParams["savefig.dpi"] = 300

# %%
top_rated = (
    df[['title', 'author', 'average_rating']]
    .dropna()
    .sort_values(by='average_rating', ascending=False)
    .head(10)
)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=top_rated,
    x="average_rating",
    y="title",
    hue="author",
    dodge=False
)
plt.title(" Top 10 Highest Rated Books")
plt.xlabel("Average Rating")
plt.ylabel("Book Title")
plt.legend(title="Author", bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.savefig("charts/top_rated_books.png", bbox_inches="tight", dpi=300)
plt.show()

# %%
genre_ratings = (
    df.groupby('genre')
    .agg(avg_rating=('average_rating', 'mean'), count=('title', 'count'))
    .query("count >= 5")
    .sort_values('avg_rating', ascending=False)
    .head(10)
)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=genre_ratings,
    x="avg_rating",
    y=genre_ratings.index,
    color="#bd3039"
)
plt.title("Top 10 Genres by Average Rating")
plt.xlabel("Average Rating")
plt.ylabel("Genre")
plt.xlim(0, 5)
plt.tight_layout()
plt.savefig("charts/top_rated_genres.png", bbox_inches="tight", dpi=300)
plt.show()

# %%
author_ratings = (
    df.groupby('author')
    .agg(avg_rating=('average_rating', 'mean'), count=('title', 'count'))
    .query("count >= 3")
    .sort_values('avg_rating', ascending=False)
    .head(10)
)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=author_ratings,
    x="avg_rating",
    y=author_ratings.index,
    color="#588157"
)
plt.title(" Top 10 Authors by Average Rating (Min. 3 Books)")
plt.xlabel("Average Rating")
plt.ylabel("Author")
plt.xlim(0, 5)
plt.tight_layout()
plt.savefig("charts/top_rated_authors.png", bbox_inches="tight", dpi=300)
plt.show()
